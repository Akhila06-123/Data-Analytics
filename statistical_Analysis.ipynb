# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhila06-123/Data-Analytics/blob/main/statistical_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
marks=[70,88,90,87,92]
hours=[2,2,3,2,3]
print("Mean",np.mean(marks))
print("median",np.median(marks))
print("standard deviation",np.std(marks))
print("variance",np.var(marks))
print("corelation",np.corrcoef(marks,hours))
# Out:
# Mean 85.4
# median 88.0
# standard deviation 7.889233169326409
# variance 62.24000000000001
# corelation [[1.         0.57957228]
#  [0.57957228 1.        ]]
